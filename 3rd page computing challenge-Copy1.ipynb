# %%
# %matplotlib nbagg
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
col = ["r(AXII)(Å)",'r(AVI)(Å)','EN(A)','EN(B)',"l(A-O)(Å)","l(B-O)(Å)","tG","τ","μ","v(A) 1", "v(A) 2","v(A) 3"]
#define structure
structure = ["cubic","orthorhombic","tetragonal","rhombohedral"]
# iterate over all categories
for i, name in enumerate(col):
    
    # filter dataframe by value
    
    # set default value to darker
    if i == i:
        j = i
        j = pd.read_csv(str(name)+".csv")
        print(j)
        j.drop('Unnamed: 0', inplace=True, axis=1)
        print(j)
        alpha = 1
        ax = sns.heatmap(j, linewidths = .5, annot=True,cbar = False, cmap='Reds')
    else:
        j = pd.read_csv(str(name)+".csv")
        print(j)
        j.drop('Unnamed: 0', inplace=True, axis=1)
        print(j)
        alpha = 0
        ax = sns.heatmap(j, linewidths = .5, annot=True,cbar = False, cmap='Reds')
        #plt.savefig(f'{name}')
        #plt.clf()
    #plt.show(f'name')
    #print(ax)
        #plt.show()
        #sns.heatmap(cf_matrix, annot=True)
# Out:
#    Unnamed: 0         0         1         2         3
# 0           0  0.323077  0.076923  0.000000  0.005128
# 1           1  0.061538  0.400000  0.030769  0.000000
# 2           2  0.005128  0.020513  0.020513  0.005128
# 3           3  0.010256  0.025641  0.010256  0.005128
#           0         1         2         3
# 0  0.323077  0.076923  0.000000  0.005128
# 1  0.061538  0.400000  0.030769  0.000000
# 2  0.005128  0.020513  0.020513  0.005128
# 3  0.010256  0.025641  0.010256  0.005128
#    Unnamed: 0         0         1         2         3
# 0           0  0.358974  0.061538  0.015385  0.005128
# 1           1  0.051282  0.441026  0.005128  0.000000
# 2           2  0.000000  0.020513  0.000000  0.005128
# 3           3  0.015385  0.010256  0.000000  0.010256
#           0         1         2         3
# 0  0.358974  0.061538  0.015385  0.005128
# 1  0.051282  0.441026  0.005128  0.000000
# 2  0.000000  0.020513  0.000000  0.005128
# 3  0.015385  0.010256  0.000000  0.010256
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib.widgets import RadioButtons
# plot confusion matrix
fig, ax = plt.subplots()
col = ['r(AXII)(Å)','r(AVI)(Å)','EN(A)','EN(B)',"l(A-O)(Å)",'l(B-O)(Å)','tG','τ','μ','v(A) 1', 'v(A) 2','v(A) 3']
structure = ["cubic","orthorhombic","tetragonal","rhombohedral"]
array = pd.read_csv('r(AXII)(Å).csv',index_col=[0])
ax.imshow(array, origin='lower')
plt.subplots_adjust(left=0.55)

# label
ax.set_xlabel('Predicted')
ax.set_ylabel('Test')

# set tick labels
ax.set_xticks([0, 1, 2, 3])
ax.set_xticklabels(structure)
ax.set_yticks([0, 1, 2, 3])
ax.set_yticklabels(structure)

# create radio box
radio_ax = plt.axes([0.0, 0.1, 0.3, 0.3], facecolor='#FFDDAA')

# create radio buttons
radio = RadioButtons(radio_ax, col)

# callback function to run when buttons are pressed
def callback(label):
    array = pd.read_csv(f'{label}.csv',index_col=[0])
    ax.imshow(array, origin='lower')

# connect function to radio object and show
radio.on_clicked(callback)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
array = pd.read_csv(f"{'tG'}.csv")
array
# Out:
#    Unnamed: 0         0         1    2         3
# 0           0  0.305556  0.055556  0.0  0.013889
# 1           1  0.013889  0.513889  0.0  0.013889
# 2           2  0.000000  0.055556  0.0  0.000000
# 3           3  0.027778  0.000000  0.0  0.000000

# %%
col[0]
# Out:
# 'r(AXII)(Å)'

# %%
fig, ax = plt.subplots()
col = ['r(AXII)(Å)','r(AVI)(Å)','EN(A)','EN(B)',"l(A-O)(Å)",'l(B-O)(Å)','tG','τ','μ','v(A) 1', 'v(A) 2','v(A) 3']
array = pd.read_csv('r(AXII)(Å).csv',index_col=[0])
ax.imshow(array, origin='lower')
plt.subplots_adjust(left=0.45)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
